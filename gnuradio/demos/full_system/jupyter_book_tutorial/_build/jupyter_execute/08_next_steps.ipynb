# %% [markdown]
# # Next Steps
#
# Congratulations! You've completed the tutorial on running experiments and capturing data.
#
# ## What You've Learned
#
# ✅ How to run experiments using four different methods
# ✅ Understanding the Bluesky document model
# ✅ Verifying data capture
# ✅ Retrieving and analyzing data
# ✅ Working with practical examples
# ✅ Troubleshooting common issues
#
# ## Continue Learning
#
# ### Advanced Topics
#
# 1. **Custom Plans** - Create your own scan patterns
#    - See: `bluesky_config/plans.py`
#    - Bluesky docs: https://blueskyproject.io/bluesky/plans.html
#
# 2. **Custom Callbacks** - Real-time data processing
#    - See: `bluesky_config/callbacks.py`
#    - Example: Live peak detection, quality monitoring
#
# 3. **Hardware Integration** - Connect GNU Radio or EJFAT
#    - See: `bluesky_config/devices.py`
#    - Example: `experiments/frequency_characterization.py`
#
# 4. **Advanced Analysis** - Statistical methods, fitting, more
#    - See: `analysis/statistics.py`
#    - See: `DATA_RETRIEVAL_AND_ANALYSIS_GUIDE.md`
#
# ### Additional Resources
#
# #### Project Documentation
# - **README.md** - Complete framework documentation
# - **TUTORIAL_RUNNING_EXPERIMENTS.md** - Extended text tutorial
# - **QUICK_REFERENCE.md** - Command cheat sheet
# - **DATA_RETRIEVAL_AND_ANALYSIS_GUIDE.md** - Complete analysis reference
# - **CLAUDE.md** - Development guidelines
#
# #### Jupyter Notebooks
# - **notebooks/quick_start.ipynb** - 5-minute quick start
# - **notebooks/data_retrieval_and_analysis_tutorial.ipynb** - 30-minute deep dive
#
# #### External Resources
# - [Bluesky Documentation](https://blueskyproject.io/)
# - [Ophyd Documentation](https://blueskyproject.io/ophyd/)
# - [DataBroker Documentation](https://blueskyproject.io/databroker/)
#
# ## Suggested Projects
#
# Apply what you've learned with these projects:
#
# ### Project 1: Custom Experiment
# Create a new experiment in `experiments/` directory:
# - Define your own scan pattern
# - Add custom metadata
# - Use specific callbacks
# - Export in your preferred format
#
# ### Project 2: Batch Analysis
# Run multiple experiments and compare:
# - Vary one parameter across runs
# - Collect all results
# - Create comparison plots
# - Export summary statistics
#
# ### Project 3: Hardware Integration
# Connect to real hardware:
# - Start with GNU Radio XML-RPC
# - Create Ophyd device wrapper
# - Run frequency scans
# - Analyze signal quality
#
# ### Project 4: Analysis Pipeline
# Build an automated analysis workflow:
# - Retrieve data automatically
# - Apply statistical analysis
# - Generate plots
# - Create summary reports
#
# ## Quick Reference
#
# ### Essential Code Pattern
#
# ```python
# from bluesky import RunEngine
# from bluesky_config.callbacks import DocumentLogger
# from ophyd import Signal
# from bluesky.plans import scan
# from bluesky_config.devices import MockDetector
#
# # Setup
# RE = RunEngine({})
# RE.subscribe(DocumentLogger('data/documents'))
#
# # Devices
# motor = Signal(name='motor', value=0)
# det = MockDetector(name='det')
#
# # Run
# uid = RE(scan([det], motor, 0, 10, 20))
# ```
#
# ### Essential Commands
#
# ```bash
# # Run experiment
# python run_experiment.py mock_experiment
#
# # View data
# python retrieve_data.py --latest --all
#
# # Export
# python retrieve_data.py --latest --export csv
#
# # Start Jupyter
# jupyter notebook
# ```
#
# ## Building the Jupyter Book
#
# To build this tutorial as a standalone website:
#
# ```bash
# # Install Jupyter Book
# pip install jupyter-book
#
# # Build the book
# cd jupyter_book_tutorial
# jupyter-book build .
#
# # View in browser
# open _build/html/index.html
# ```
#
# ## Stay Connected
#
# - EJFAT GitHub: https://github.com/JeffersonLab/E2SAR
# - Bluesky Discussions: https://github.com/bluesky/bluesky/discussions
#
# ## Final Thoughts
#
# You now have the tools to:
# - Run controlled experiments
# - Capture high-quality data
# - Verify data integrity
# - Analyze and visualize results
# - Export and share findings
#
# The Bluesky framework provides a solid foundation for scientific data acquisition.
# As you gain experience, explore its advanced features and customize it for your needs.
#
# **Happy experimenting!** 🚀
