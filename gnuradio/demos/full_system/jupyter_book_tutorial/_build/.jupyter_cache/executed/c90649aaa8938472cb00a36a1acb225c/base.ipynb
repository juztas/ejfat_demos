# %%
# Verify imports
try:
    from bluesky import RunEngine
    from ophyd import Signal
    from databroker import Broker
    import matplotlib.pyplot as plt
    import pandas as pd
    import scipy
    
    print("✓ All required packages are available!")
    print("\nPackage versions:")
    print(f"  Bluesky: {__import__('bluesky').__version__}")
    print(f"  Ophyd: {__import__('ophyd').__version__}")
    print(f"  Pandas: {pd.__version__}")
    print(f"  Matplotlib: {matplotlib.__version__}")
    print("\nYou're ready to start!")
    
except ImportError as e:
    print(f"❌ Missing package: {e}")
    print("\nPlease install missing packages:")
    print("  pip install bluesky ophyd databroker matplotlib pandas scipy")
# Out:
# ❌ Missing package: No module named 'bluesky'
#
# Please install missing packages:
#   pip install bluesky ophyd databroker matplotlib pandas scipy

# %%
import os
from pathlib import Path

current_dir = Path.cwd()
print(f"Current directory: {current_dir}")

# Check if we're in the right place
expected_files = ['run_experiment.py', 'retrieve_data.py', 'config.py']
missing = [f for f in expected_files if not (current_dir / f).exists()]

if missing:
    print(f"\n⚠️  Missing expected files: {missing}")
    print("\nYou may need to change directory:")
    print("  import os")
    print("  os.chdir('/path/to/full_system')")
else:
    print("\n✓ You're in the correct directory!")
# Out:
# Current directory: /Users/yak/Projects/EJFAT/ejfat_demos/gnuradio/demos/full_system/jupyter_book_tutorial
#
# ⚠️  Missing expected files: ['run_experiment.py', 'retrieve_data.py', 'config.py']
#
# You may need to change directory:
#   import os
#   os.chdir('/path/to/full_system')
